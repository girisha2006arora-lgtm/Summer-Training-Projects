# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle, Arc,Ellipse
from matplotlib.patches import Polygon
import numpy as np

# %%
fig, ax= plt.subplots()
mycircle=Circle([16,14],3,fill=True,facecolor='#240042',edgecolor='white')
a=Circle([16,14],3.1,fill=True,color='#00BFFF', alpha=0.20)
b=Circle([16,14],3.2,fill=True,color='#00BFFF', alpha=0.16)
c=Circle([16,14],3.3,fill=True,color='#00FFFF', alpha=0.12)
d=Circle([16,14],3.4,fill=True,color='#00FFFF', alpha=0.12)
e=Circle([16,14],3.5,fill=True,color='#00FFFF', alpha=0.08)
f=Circle([16,14],3.6,fill=True,color='#66FFFF', alpha=0.08)
g=Circle([16,14],3.7,fill=True,color='#66FFFF', alpha=0.06)
h=Circle([16,14],3.8,fill=True,color='#66FFFF', alpha=0.06)
i=Circle([16,14],3.9,fill=True,color='#66FFFF', alpha=0.04)
j=Circle([16,14],4,fill=True,color='#66FFFF', alpha=0.04)
k=Circle([16,14],4,fill=True,color='white', alpha=0.02)

ax.add_patch(mycircle)
ax.add_patch(a)
ax.add_patch(b)
ax.add_patch(c)
ax.add_patch(d)
ax.add_patch(e)
ax.add_patch(f)
ax.add_patch(g)
ax.add_patch(h)
ax.add_patch(i)
ax.add_patch(j)
ax.add_patch(k)

americas = [(13.0,16.7),(13.2,17.0),(13.6,17.2),(14.2,17.1),(14.8,16.8),(15.0,16.4),(14.9,16.0),(14.7,15.6),(14.4,15.3),(14.0,15.1),(13.6,15.0),(13.3,14.7),(13.2,14.3),
    (13.4,13.9),(13.8,13.6),(14.2,13.3),(14.6,12.9),(14.9,12.4),(15.0,11.9),(14.8,11.4),(14.5,11.0),(14.2,10.9),(13.9,11.2),(13.7,11.8),(13.6,12.5),
    (13.5,13.2),(13.3,13.9),(13.0,14.8)]


eurasia = [(16.9,16.6),(17.3,16.9),(17.8,17.1),(18.4,17.0),(19.0,16.8),(19.5,16.4),(19.8,15.9),(19.8,15.4),(19.5,15.0),(19.1,14.8),(18.7,14.7),(18.3,14.8),
    (17.9,15.0),(17.5,15.2),
    (17.2,15.5),
    (16.9,16.0)
]
africa = [
    (17.2,14.5),
    (17.6,14.3),
    (18.0,14.0),
    (18.3,13.5),
    (18.5,13.0),
    (18.4,12.4),
    (18.2,11.9),
    (17.9,11.5),
    (17.5,11.4),
    (17.2,11.7),
    (17.0,12.2),
    (16.9,12.8),
    (17.0,13.5)
]
australia = [
    (18.2,11.8),
    (18.5,11.7),
    (18.9,11.8),
    (19.1,12.0),
    (19.0,12.3),
    (18.7,12.4),
    (18.3,12.3),
    (18.1,12.1)
]


for points in [americas,eurasia,africa,australia]:
    continent=Polygon(points,closed=True,facecolor="#7AC943",edgecolor="#4C8A2B",linewidth=1)
    continent.set_clip_path(mycircle)
    ax.add_patch(continent)

##For making latitude lines 
for hh in [1,2.5,4,5.5]:

    arc = Arc((16,14),
              width=6,
              height=hh,
              theta1=0,
              theta2=360,
              color="cyan",
              lw=0.5)

    ax.add_patch(arc)

##For making longitude lines
for w in [1, 2.5, 4, 5.5]:
    arcc = Arc((16,14),
              width=w,
              height=6,
              theta1=90,
              theta2=270,
              color="cyan",
              lw=0.5)

    ax.add_patch(arcc)
    
    arcc = Arc((16,14),
              width=w,
              height=6,
              theta1=-90,
              theta2=90,
              color="cyan",
              lw=0.5)

    ax.add_patch(arcc)
    
ax.set_aspect('equal')
ax.autoscale_view()   

## Giving background colour 
ax.set_facecolor("#020B1F")
# Star center
circle3 = Circle((12.5,10.5), 0.06,
                 facecolor="white",
                 edgecolor="none")

# Glow layers
a0 = Circle((12.5,10.5),0.11, color="#FFFACD", alpha=0.28)
b0 = Circle((12.5,10.5),0.13, color="#FFE066", alpha=0.22)
c0 = Circle((12.5,10.5),0.15, color="#FFD700", alpha=0.16)
d0 = Circle((12.5,10.5),0.17, color="#FFF8DC", alpha=0.12)
e0 = Circle((12.5,10.5),0.20, color="#FFF8DC", alpha=0.08)
f0 = Circle((12.5,10.5),0.23, color="#FFFFCC", alpha=0.05)
g0 = Circle((12.5,10.5),0.26, color="#FFFFCC", alpha=0.03)

# Add from largest to smallest
for star in [g0, f0, e0, d0, c0, b0, a0, circle3]:
    ax.add_patch(star)
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)   # Makes the stars appear the same every run

# Canvas size (change according to your figure)
xmin, xmax = 10, 13
ymin, ymax = 10, 20

# Generate 1000 random star positions
x = np.random.uniform(xmin, xmax, 200)
y = np.random.uniform(ymin, ymax, 200)

# Random sizes
sizes = np.random.uniform(1, 12, 200)

# Random brightness (alpha)
alpha = np.random.uniform(0.3, 1.0, 200)

# Draw stars
for i in range(200):
    plt.scatter(x[i], y[i],
                s=sizes[i],
                color='white',
                alpha=alpha[i],
                edgecolors='none',
                zorder=1)
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)   # Makes the stars appear the same every run

# Canvas size (change according to your figure)
xmin, xmax = 10, 20
ymin, ymax = 10, 11

# Generate 1000 random star positions
x = np.random.uniform(xmin, xmax, 200)
y = np.random.uniform(ymin, ymax, 200)

# Random sizes
sizes = np.random.uniform(1, 12, 200)

# Random brightness (alpha)
alpha = np.random.uniform(0.3, 1.0, 200)

# Draw stars
for i in range(200):
    plt.scatter(x[i], y[i],
                s=sizes[i],
                color='white',
                alpha=alpha[i],
                edgecolors='none',
                zorder=1)
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)   # Makes the stars appear the same every run

# Canvas size (change according to your figure)
xmin, xmax = 10, 20
ymin, ymax = 17.5, 20

# Generate 1000 random star positions
x = np.random.uniform(xmin, xmax, 200)
y = np.random.uniform(ymin, ymax, 200)

# Random sizes
sizes = np.random.uniform(1, 12, 200)

# Random brightness (alpha)
alpha = np.random.uniform(0.3, 1.0, 200)

# Draw stars
for i in range(200):
    plt.scatter(x[i], y[i],
                s=sizes[i],
                color='white',
                alpha=alpha[i],
                edgecolors='none',
                zorder=1)
    import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)   # Makes the stars appear the same every run

# Canvas size (change according to your figure)
xmin, xmax = 19, 22
ymin, ymax = 10, 20

# Generate 1000 random star positions
x = np.random.uniform(xmin, xmax, 200)
y = np.random.uniform(ymin, ymax, 200)

# Random sizes
sizes = np.random.uniform(1, 12, 200)

# Random brightness (alpha)
alpha = np.random.uniform(0.3, 1.0, 200)

# Draw stars
for i in range(200):
    plt.scatter(x[i], y[i],
                s=sizes[i],
                color='white',
                alpha=alpha[i],
                edgecolors='none',
                zorder=1)
circle4 = Circle((12.5,18), 0.06,
                 facecolor="white",
                 edgecolor="none")

# Glow layers
a0 = Circle((12.5,18),0.11, color="#FFFACD", alpha=0.28)
b0 = Circle((12.5,18),0.13, color="#FFE066", alpha=0.22)
c0 = Circle((12.5,18),0.15, color="#FFD700", alpha=0.16)
d0 = Circle((12.5,18),0.17, color="#FFF8DC", alpha=0.12)
e0 = Circle((12.5,18),0.20, color="#FFF8DC", alpha=0.08)
f0 = Circle((12.5,18),0.23, color="#FFFFCC", alpha=0.05)
g0 = Circle((12.5,18),0.26, color="#FFFFCC", alpha=0.03)

for star in [g0, f0, e0, d0, c0, b0, a0, circle4]:
    ax.add_patch(star)

circle5 = Circle((21.5,15.5), 0.06,
                 facecolor="white",
                 edgecolor="none")

# Glow layers
a0 = Circle((21.5,15.5),0.11, color="#FFFACD", alpha=0.28)
b0 = Circle((21.5,15.5),0.13, color="#FFE066", alpha=0.22)
c0 = Circle((21.5,15.5),0.15, color="#FFD700", alpha=0.16)
d0 = Circle((21.5,15.5),0.17, color="#FFF8DC", alpha=0.12)
e0 = Circle((21.5,15.5),0.20, color="#FFF8DC", alpha=0.08)
f0 = Circle((21.5,15.5),0.23, color="#FFFFCC", alpha=0.05)
g0 = Circle((21.5,15.5),0.26, color="#FFFFCC", alpha=0.03)

for star in [g0, f0, e0, d0, c0, b0, a0, circle5]:
    ax.add_patch(star)

circle6 = Circle((20,19.5), 0.06,
                 facecolor="white",
                 edgecolor="none")

# Glow layers
a0 = Circle((20,19.5),0.11, color="#FFFACD", alpha=0.28)
b0 = Circle((20,19.5),0.13, color="#FFE066", alpha=0.22)
c0 = Circle((20,19.5),0.15, color="#FFD700", alpha=0.16)
d0 = Circle((20,19.5),0.17, color="#FFF8DC", alpha=0.12)
e0 = Circle((20,19.5),0.20, color="#FFF8DC", alpha=0.08)
f0 = Circle((20,19.5),0.23, color="#FFFFCC", alpha=0.05)
g0 = Circle((20,19.5),0.26, color="#FFFFCC", alpha=0.03)

for star in [g0, f0, e0, d0, c0, b0, a0, circle6]:
    ax.add_patch(star)

circle7 = Circle((19,16.5), 0.0099,
                 facecolor="white",
                 edgecolor="none")

a0 = Circle((19,16.5),0.010, color="white", alpha=1)
b0 = Circle((19,16.5),0.012, color="#FFF0F8", alpha=0.85)
c0 = Circle((19,16.5),0.015, color="#FFD1DC", alpha=0.65)
d0 = Circle((19,16.5),0.018, color="#FFB6C1", alpha=0.45)
e0 = Circle((19,16.5),0.022, color="#FF69B4", alpha=0.25)
f0 = Circle((19,16.5),0.027, color="#FF1493", alpha=0.12)
g0 = Circle((19,16.5),0.033, color="#FF69B4", alpha=0.05)

for star in [g0, f0, e0, d0, c0, b0, a0, circle7]:
    ax.add_patch(star)

circle8 = Circle((11,17), 0.0076,
                 facecolor="white",
                 edgecolor="none")

a0 = Circle((11,17),0.10, color="white", alpha=1)
b0 = Circle((11,17),0.12, color="#FFF0F8", alpha=0.85)
c0 = Circle((11,17),0.15, color="#FFD1DC", alpha=0.65)
d0 = Circle((11,17),0.18, color="#FFB6C1", alpha=0.45)
e0 = Circle((11,17),0.22, color="#FF69B4", alpha=0.25)
f0 = Circle((11,17),0.27, color="#FF1493", alpha=0.12)
g0 = Circle((11,17),0.33, color="#FF69B4", alpha=0.05)

for star in [g0, f0, e0, d0, c0, b0, a0, circle8]:
    ax.add_patch(star)

circle9 = Circle((21,11), 0.08,
                 facecolor="white",
                 edgecolor="none")
a = Circle((21,11),0.15,color="white",alpha=1)
b = Circle((21,11),0.25,color="#FFE6F2",alpha=0.9)
c = Circle((21,11),0.40,color="#FFB6C1",alpha=0.5)
d = Circle((21,11),0.60,color="#FF69B4",alpha=0.18)
e = Circle((21,11),0.80,color="#FF1493",alpha=0.05)

for star in [e,d,c,b,a,circle9]:
    ax.add_patch(star)

###Adding purple stars
circle12 = Circle((19,16), 0.0099,
                 facecolor="white",
                 edgecolor="none")

a = Circle((12,27),0.10,color="white",alpha=1)
b = Circle((12,27),0.13,color="#F8F0FF",alpha=0.8)
c = Circle((12,27),0.16,color="#DDA0DD",alpha=0.55)
d = Circle((12,27),0.20,color="#BA55D3",alpha=0.30)
e = Circle((12,27),0.25,color="#8A2BE2",alpha=0.15)
f = Circle((12,27),0.32,color="#9370DB",alpha=0.06)

for star in [g0, f0, e0, d0, c0, b0, a0, circle12]:
    ax.add_patch(star)

# Core
core = Circle((19,16), 0.06,
              facecolor="white",
              edgecolor="none")

a = Circle((19,16),0.09,color="white",alpha=0.90)
b = Circle((19,16),0.12,color="#F8F0FF",alpha=0.70)
c = Circle((19,16),0.16,color="#E6CCFF",alpha=0.50)
d = Circle((19,16),0.21,color="#DDA0DD",alpha=0.30)
e = Circle((19,16),0.27,color="#BA55D3",alpha=0.18)
f = Circle((19,16),0.34,color="#8A2BE2",alpha=0.08)

for star in [f,e,d,c,b,a,core]:
    ax.add_patch(star)

cores = Circle((10,12), 0.06,
              facecolor="white",
              edgecolor="none")

a = Circle((10,12),0.09,color="white",alpha=0.90)
b = Circle((10,12),0.12,color="#F8F0FF",alpha=0.70)
c = Circle((10,12),0.16,color="#E6CCFF",alpha=0.50)
d = Circle((10,12),0.21,color="#DDA0DD",alpha=0.30)
e = Circle((10,12),0.27,color="#BA55D3",alpha=0.18)
f = Circle((10,12),0.34,color="#8A2BE2",alpha=0.08)

for star in [f,e,d,c,b,a,cores]:
    ax.add_patch(star)

coress = Circle((20,11.5),0.06,color="white")

a = Circle((20,11.5),0.09,color="white",alpha=0.90)
b = Circle((20,11.5),0.12,color="#B0E0FF",alpha=0.75)
c = Circle((20,11.5),0.16,color="#00E5FF",alpha=0.55)
d = Circle((20,11.5),0.21,color="#00BFFF",alpha=0.35)
e = Circle((20,11.5),0.27,color="#007BFF",alpha=0.18)
f = Circle((20,11.5),0.34,color="#0033CC",alpha=0.08)

for star in [f,e,d,c,b,a,coress]:
    ax.add_patch(star)

x, y = 19.0, 16.0

# Outer Glow
g9 = Circle((x,y),1.60,color="white",alpha=0.015)
g8 = Circle((x,y),1.40,color="#FFF8DC",alpha=0.025)
g7 = Circle((x,y),1.20,color="#FFF8DC",alpha=0.035)
g6 = Circle((x,y),1.00,color="#FFFACD",alpha=0.05)
g5 = Circle((x,y),0.80,color="#FFFACD",alpha=0.08)
g4 = Circle((x,y),0.60,color="#FFFACD",alpha=0.12)
g3 = Circle((x,y),0.42,color="#FFF44F",alpha=0.22)
g2 = Circle((x,y),0.30,color="#FFE066",alpha=0.38)
g1 = Circle((x,y),0.18,color="#FFF8E7",alpha=0.75)

# Bright Core
core = Circle((x,y),0.09,color="white")

for star in [g9,g8,g7,g6,g5,g4,g3,g2,g1,core]:
    ax.add_patch(star)
plt.show()
